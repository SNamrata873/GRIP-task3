# %% [markdown]
# <img src = "https://internship.thesparksfoundation.info/assests/img/logo.png" width = "200" align = "left">

# %% [markdown]
# # GRIP : THE SPARKS FOUNDATION

# %% [markdown]
# ### Data Science and Business Analytics Internship

# %% [markdown]
# ## Author: Namrata Sharma¶
#
# ### TASK 3 ::  Exploratory Data Analysis(Retail) - SampleSuperstore DataSet
#
# Find out the weak areas where you can work to make more profit.
# What all business problems you can derive by exploring the data?

# %% [markdown]
# ### Exploratory Data Analysis
# Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.

# %% [markdown]
# ### IMPORTING PACKAGES

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\NAMRATA\Downloads\SampleSuperstore.csv")
df.head(-5)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9984  Standard Class   Consumer  United States       Long Beach    New York
# 9985  Standard Class   Consumer  United States       Long Beach    New York
# 9986  Standard Class   Consumer  United States      Los Angeles  California
# 9987  Standard Class  Corporate  United States           Athens     Georgia
# 9988  Standard Class  Corporate  United States           Athens     Georgia
#
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Check no of rows and columns in the dataset
df.shape
# Out:
# (9994, 13)

# %%
#Unique Values DataSet
for i in df.columns:
    print(i,len(df[i].unique()))
# Out:
# Ship Mode 4
# Segment 3
# Country 1
# City 531
# State 49
# Postal Code 631
# Region 4
# Category 3
# Sub-Category 17
# Sales 5825
# Quantity 14
# Discount 12
# Profit 7287

# %%
# To know about the total sales and the profit generated by the retail store.

print('Sales:',df['Sales'].sum())
print('Profit:',df['Profit'].sum())
# Out:
# Sales: 2297200.8603000003
# Profit: 286397.0217

# %% [markdown]
# ## UNDERSTANDING THE DATASET
# #### What are the different ship mode ?

# %%
diff_ship_mode=df['Ship Mode'].unique()
for x in diff_ship_mode:
    print(x)
# Out:
# Second Class
# Standard Class
# First Class
# Same Day

# %% [markdown]
# #### What are the different segments ?

# %%
diff_segment=df['Segment'].unique()
for x in diff_segment:
    print(x)
# Out:
# Consumer
# Corporate
# Home Office

# %% [markdown]
# #### What are the different Region ?

# %%
diff_Region=df['Region'].unique()
for x in diff_Region:
    print(x)
# Out:
# South
# West
# Central
# East

# %% [markdown]
# #### What are the different category ?

# %%
diff_category=df['Category'].unique()
for x in diff_category:
    print(x)
# Out:
# Furniture
# Office Supplies
# Technology

# %% [markdown]
# #### What are the different sub-category ?

# %%
diff_sub_category=df['Sub-Category'].unique()
for x in diff_sub_category:
    print(x)
# Out:
# Bookcases
# Chairs
# Labels
# Tables
# Storage
# Furnishings
# Art
# Phones
# Binders
# Appliances
# Paper
# Accessories
# Envelopes
# Fasteners
# Supplies
# Machines
# Copiers

# %% [markdown]
# #### What are the Region wise Sales value ?

# %%
df.groupby("Region").Sales.sum()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %% [markdown]
# #### What is the maximum sale ?

# %%
df.Sales.max()
# Out:
# 22638.48

# %% [markdown]
# #### What is the minimum sale ?

# %%
df.Sales.min()
# Out:
# 0.444

# %% [markdown]
# #### What are the Top 10 selling products ?

# %%
df.groupby("Sub-Category").Sales.sum().sort_values(ascending=False).head()
# Out:
# Sub-Category
# Phones     330007.054
# Chairs     328449.103
# Storage    223843.608
# Tables     206965.532
# Binders    203412.733
# Name: Sales, dtype: float64

# %% [markdown]
# #### What are the Top 5 Profitable Products ?

# %%
df.groupby("Sub-Category").Profit.sum().sort_values(ascending=False).head(5)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Name: Profit, dtype: float64

# %% [markdown]
# #### What is the total profit?

# %%
df['Profit'].sum()
# Out:
# 286397.0217

# %% [markdown]
# ### Visualization of Data

# %%
g=sns.pairplot(df)
g.map_upper(sns.scatterplot, color='skyblue')
g.map_lower(sns.scatterplot, color='pink')
g.map_diag(plt.hist, color='purple')
plt.show()

# %%
#ploting heat map
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='Oranges')
# Out:
# <AxesSubplot:>

# %%
# total profit vs sales
fig,axes = plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total profit VS sales ")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Profit'].agg(sum),x='Sales',y='Profit',ax=axes[1])
df.groupby('Sub-Category')['Sales','Profit'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\NAMRATA\AppData\Local\Temp/ipykernel_14088/1975343138.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sns.barplot(data=df.groupby('Sub-Category')['Sales','Profit'].agg(sum),x='Sales',y='Profit',ax=axes[1])
# C:\Users\NAMRATA\AppData\Local\Temp/ipykernel_14088/1975343138.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sub-Category')['Sales','Profit'].agg(sum).plot(kind='bar',ax=axes[0])

# %%
# total sales vs quantity
fig,axes = plt.subplots(1,2,figsize=(14,5))
fig.suptitle("Total Sales VS Quantity ")
sns.barplot(data=df.groupby('Sub-Category')['Sales','Quantity'].agg(sum),x='Sales',y='Quantity',ax=axes[1])
df.groupby('Sub-Category')['Sales','Quantity'].agg(sum).plot(kind='bar',ax=axes[0])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\NAMRATA\AppData\Local\Temp/ipykernel_14088/1984020025.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sns.barplot(data=df.groupby('Sub-Category')['Sales','Quantity'].agg(sum),x='Sales',y='Quantity',ax=axes[1])
# C:\Users\NAMRATA\AppData\Local\Temp/ipykernel_14088/1984020025.py:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sub-Category')['Sales','Quantity'].agg(sum).plot(kind='bar',ax=axes[0])

# %%
#KDE Plot
plt.figure(figsize=(10,7))
sns.kdeplot(df['Sales'], color='red', label='Sales', shade=True, bw_method=20)
sns.kdeplot(df['Profit'], color='blue', label='Profit', shade=True, bw_method=20)
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')
df.plot(kind = "scatter",figsize = (10,5), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap = "viridis")
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Interdependent of Sales,Profits and Discounts",fontsize = 16)

plt.show()

# %% [markdown]
# The graph clearly shows that if we give more Discount on our products sales increases but profit decreases.

# %%
# Profit vs discount
sns.lineplot(x='Discount',y='Profit',label='Profit',data=df)
plt.title('PROFIT VS DISCOUNT')
plt.legend()
plt.show()

# %% [markdown]
# As Discount increases the profit decreases till 50% discount after that profit shows an increament with discount. Their is some correlation between profit and discount
#
# Upto 0-10% discount and more than 60% discount generates profit 40% discount has very less profit

# %%
# Quantity Vs Profit profile using lineplot
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=df)
plt.title('PROFIT VS QUANTITY')
plt.legend()
plt.show()

# %%
# Let's visualize effect of discount on sales and profit
plt.figure(figsize=(12,5),dpi=90)

plt.subplot(1,2,1)
sns.lineplot(data=df,x='Discount',y='Sales')
plt.title('Discount vs sales')

plt.subplot(1,2,2)
sns.lineplot(data=df,x='Discount',y='Profit')
plt.title('Discount vs Profit')
plt.axhline(y=0,color='red');

# %% [markdown]
# Analysis from above plots:- Providing discounts on products has brought in loss in most of the cases, so maybe providing discounts should not be considered

# %% [markdown]
# #### Some important Findings
#
# 1) The features Profit and Discounts are highly related.
#
# 2) Over Less quantity of products also the sales were high.
#
# 3) The maximum quantity of product in demand was in range 2-5.
#
# 4) The mode of shipping doesn't affect much to the sales
#
# 5) The Home Office provides highest sales followed by Corporate by a slight variation
#
# #### The areas where one can work to make more profit are :
#
# 1)We should limit sales of furniture and increase that of technology and office suppliers as furniture has very less profit as compared to others.
#
# 2)Considering the sub-categories sales of tables should be minimized.
#
# 3)Increase sales more in the east as profit is more.
#
# 4)We should concentrate on the states like 'New York' and 'California' to make more profits
